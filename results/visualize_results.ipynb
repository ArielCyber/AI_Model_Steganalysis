# %%
import pandas as pd

chosen_zoo = "mnist"

df = pd.read_csv(f'results_{chosen_zoo}.csv')
df_lsb_top_clf = df.loc[df.groupby('lsb')['f1'].idxmax()]
df_lsb_top_clf.sort_values(by=['lsb'], inplace=False, ascending=[False])
#df.sort_values(by=['lsb', 'clf'], inplace=True, ascending=[False, True])
#df
#df[]
# Out:
#     lsb               clf  accuracy  recall  precision        f1  \
# 68   23      RandomForest    0.9260   0.888   0.961039  0.923077
# 65   22      RandomForest    0.8945   0.860   0.923738  0.890730
# 62   21      RandomForest    0.7095   0.649   0.738339  0.690793
# 58   20  GradientBoosting    0.4695   0.461   0.468973  0.464952
# 55   19  GradientBoosting    0.4360   0.438   0.436255  0.437126
# 52   18  GradientBoosting    0.4235   0.440   0.425944  0.432858
# 49   17  GradientBoosting    0.4365   0.182   0.370672  0.244131
# 46   16  GradientBoosting    0.4280   0.207   0.370968  0.265725
# 43   15  GradientBoosting    0.4225   0.160   0.336842  0.216949
# 40   14  GradientBoosting    0.4190   0.242   0.374613  0.294046
# 37   13  GradientBoosting    0.4285   0.168   0.350731  0.227181
# 34   12  GradientBoosting    0.3980   0.181   0.319788  0.231162
# 31   11  GradientBoosting    0.3765   0.351   0.369863  0.360185
# 28   10  GradientBoosting    0.3605   0.311   0.345172  0.327196
# 25    9  GradientBoosting    0.3440   0.286   0.323529  0.303609
# 22    8  GradientBoosting    0.3405   0.271   0.314750  0.291241
# 19    7  GradientBoosting    0.3390   0.279   0.317045  0.296809
# 16    6  GradientBoosting    0.3495   0.258   0.315789  0.283985
# 13    5  GradientBoosting    0.3340   0.274   0.311364  0.291489
# 10    4  GradientBoosting    0.3385   0.283   0.318335  0.299629
# 7     3  GradientBoosting    0.3375   0.302   0.325081  0.313116
# 4     2  GradientBoosting    0.3355   0.276   0.313280  0.293461
# 1     1  GradientBoosting    0.3300   0.291   0.315618  0.302810
#
#                    conf_mat
# 68  [[964  36]\n [112 888]]
# 65  [[929  71]\n [140 860]]
# 62  [[770 230]\n [351 649]]
# 58  [[478 522]\n [539 461]]
# 55  [[434 566]\n [562 438]]
# 52  [[407 593]\n [560 440]]
# 49  [[691 309]\n [818 182]]
# 46  [[649 351]\n [793 207]]
# 43  [[685 315]\n [840 160]]
# 40  [[596 404]\n [758 242]]
# 37  [[689 311]\n [832 168]]
# 34  [[615 385]\n [819 181]]
# 31  [[402 598]\n [649 351]]
# 28  [[410 590]\n [689 311]]
# 25  [[402 598]\n [714 286]]
# 22  [[410 590]\n [729 271]]
# 19  [[399 601]\n [721 279]]
# 16  [[441 559]\n [742 258]]
# 13  [[394 606]\n [726 274]]
# 10  [[394 606]\n [717 283]]
# 7   [[373 627]\n [698 302]]
# 4   [[395 605]\n [724 276]]
# 1   [[369 631]\n [709 291]]
