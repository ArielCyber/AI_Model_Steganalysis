# %% [markdown]
# # Unsupervised Experiments

# %%
import pandas as pd

chosen_zoo = "mnist"
msb = True

df = pd.read_csv(f'results_unsupervised{"_msb" if msb else ""}.csv')
df[(df["zoo"] == chosen_zoo) & (df["lsb"] >= 20)]
# Out:
#       zoo spacer_type  spacer_value  lsb  accuracy  recall  precision  \
# 19  mnist         eps       0.00001   20  0.893077  1.0000   0.877963
# 20  mnist         eps       0.00001   21  0.893077  1.0000   0.877963
# 21  mnist         eps       0.00001   22  0.893077  1.0000   0.877963
# 22  mnist         eps       0.00001   23  0.893077  1.0000   0.877963
# 42  mnist         std       2.00000   20  0.816923  0.7818   0.975299
# 43  mnist         std       2.00000   21  0.984462  0.9996   0.980577
# 44  mnist         std       2.00000   22  0.984769  1.0000   0.980584
# 45  mnist         std       2.00000   23  0.984615  0.9998   0.980581
#
#           f1
# 19  0.935016
# 20  0.935016
# 21  0.935016
# 22  0.935016
# 42  0.867895
# 43  0.989997
# 44  0.990197
# 45  0.990097

# %% [markdown]
# # Supervised Experiments

# %%
import pandas as pd

chosen_zoo = "svhn" # mnist, cifar10, stl10, svhn
msb = True

df = pd.read_csv(f'results_supervised{"_msb" if msb else ""}.csv')
df_only_chosen_zoo = df[df["zoo"]==chosen_zoo]
df_lsb_top_clf = df_only_chosen_zoo.loc[df_only_chosen_zoo.groupby('lsb')['f1'].idxmax()]
df_lsb_top_clf.sort_values(by=['lsb'], inplace=False, ascending=[False])
#df.sort_values(by=['lsb', 'clf'], inplace=True, ascending=[False, True])
#df
#df[]
# Out:
#       zoo feature_type  lsb                   clf  accuracy  recall  \
# 734  svhn      weights   23  HistGradientBoosting       1.0     1.0
# 732  svhn      weights   22  HistGradientBoosting       1.0     1.0
# 730  svhn      weights   21  HistGradientBoosting       1.0     1.0
# 728  svhn      weights   20  HistGradientBoosting       1.0     1.0
# 726  svhn      weights   19  HistGradientBoosting       1.0     1.0
# 724  svhn      weights   18  HistGradientBoosting       1.0     1.0
# 722  svhn      weights   17  HistGradientBoosting       1.0     1.0
# 720  svhn      weights   16  HistGradientBoosting       1.0     1.0
# 718  svhn      weights   15  HistGradientBoosting       1.0     1.0
# 716  svhn      weights   14  HistGradientBoosting       1.0     1.0
# 714  svhn      weights   13  HistGradientBoosting       1.0     1.0
# 712  svhn      weights   12  HistGradientBoosting       1.0     1.0
# 710  svhn      weights   11  HistGradientBoosting       1.0     1.0
# 708  svhn      weights   10  HistGradientBoosting       1.0     1.0
# 706  svhn      weights    9  HistGradientBoosting       1.0     1.0
# 704  svhn      weights    8  HistGradientBoosting       1.0     1.0
# 702  svhn      weights    7  HistGradientBoosting       1.0     1.0
# 700  svhn      weights    6  HistGradientBoosting       1.0     1.0
# 698  svhn      weights    5  HistGradientBoosting       1.0     1.0
# 696  svhn      weights    4  HistGradientBoosting       1.0     1.0
# 694  svhn      weights    3  HistGradientBoosting       1.0     1.0
# 692  svhn      weights    2  HistGradientBoosting       1.0     1.0
# 690  svhn      weights    1  HistGradientBoosting       1.0     1.0
#
#      precision   f1                 conf_mat
# 734        1.0  1.0  [[818   0]\n [  0 817]]
# 732        1.0  1.0  [[818   0]\n [  0 817]]
# 730        1.0  1.0  [[818   0]\n [  0 817]]
# 728        1.0  1.0  [[818   0]\n [  0 817]]
# 726        1.0  1.0  [[818   0]\n [  0 817]]
# 724        1.0  1.0  [[818   0]\n [  0 817]]
# 722        1.0  1.0  [[818   0]\n [  0 817]]
# 720        1.0  1.0  [[818   0]\n [  0 817]]
# 718        1.0  1.0  [[818   0]\n [  0 817]]
# 716        1.0  1.0  [[818   0]\n [  0 817]]
# 714        1.0  1.0  [[818   0]\n [  0 817]]
# 712        1.0  1.0  [[818   0]\n [  0 817]]
# 710        1.0  1.0  [[818   0]\n [  0 817]]
# 708        1.0  1.0  [[818   0]\n [  0 817]]
# 706        1.0  1.0  [[818   0]\n [  0 817]]
# 704        1.0  1.0  [[818   0]\n [  0 817]]
# 702        1.0  1.0  [[818   0]\n [  0 817]]
# 700        1.0  1.0  [[818   0]\n [  0 817]]
# 698        1.0  1.0  [[818   0]\n [  0 817]]
# 696        1.0  1.0  [[818   0]\n [  0 817]]
# 694        1.0  1.0  [[818   0]\n [  0 817]]
# 692        1.0  1.0  [[818   0]\n [  0 817]]
# 690        1.0  1.0  [[818   0]\n [  0 817]]
